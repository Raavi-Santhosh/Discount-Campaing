# %% [raw]
# Logistic Regression:
#
# Accuracy : 0.914327917282127
# True Negative : 1663
# False Positive : 149
# False Negative : 25
# True Positive : 194
# Precision : 0.565597667638484 Recall : 0.8858447488584474
# F1 Score : 0.6903914590747331
# Area under the curve = 0.9018075841422479
# My model is lacking the confidence of 25.86 %
#
# Decision Trees (without CV and max_Depth 7)
#
# Accuracy : 0.9290989660265879
# True Negative : 1696
# False Positive : 116
# False Negative : 28
# True Positive : 191
# Precision : 0.6221498371335505
# Recall : 0.8721461187214612
# F1 Score : 0.726235741444867
# Area under the curve = 0.9040642293386555
# My model is lacking the confidence of 32.55 %
#
# Decision Tree (Tuning Hyper parameter max_depth without crossvalidation)
#
# Accuracy :  0.9384539635647464
# True Negative :  1710
# False Positive :  102
# False Negative :  23
# True Positive :  196
# Precision :  0.6577181208053692
# Recall :  0.8949771689497716
# KS_score :  0.8386857782212949
# F1 Score :  0.758220502901354
# Area under the curve =  0.9193428891106474
# My model is lacking the confidence of  48.54 %
#
# Decision Tree (Tuning Hyper parameter with Cross validation)
#
# Accuracy :  0.9015263417035942
# True Negative :  1626
# False Positive :  186
# False Negative :  14
# True Positive :  205
# Precision :  0.5242966751918159
# Recall :  0.9360730593607306
# KS_score :  0.8334240527382141
# F1 Score :  0.6721311475409837
# Area under the curve =  0.9167120263691071
# My model is lacking the confidence of  29.22 %
#
# Random Forest
#
# Accuracy :  0.965534219596258
# True Negative :  1796
# False Positive :  16
# False Negative :  54
# True Positive :  165
# Precision :  0.9116022099447514
# Recall :  0.7534246575342466
# KS_score :  0.7445946354591914
# F1 Score :  0.825
# Area under the curve =  0.8722973177295956
# My model is lacking the confidence of  8.35 %
#
# Extra Trees
#
# Accuracy :  0.9630723781388478
# True Negative :  1769
# False Positive :  43
# False Negative :  32
# True Positive :  187
# Precision :  0.8130434782608695
# Recall :  0.8538812785388128
# KS_score :  0.830150594212102
# F1 Score :  0.8329621380846325
# Area under the curve =  0.9150752971060511
# My model is lacking the confidence of  11.99 %
#
# Gradient Boosting
#
# Accuracy :  0.9724273756770064
# True Negative :  1795
# False Positive :  17
# False Negative :  39
# True Positive :  180
# Precision :  0.9137055837563451
# Recall :  0.821917808219178
# KS_score :  0.8125359097644319
# F1 Score :  0.8653846153846154
# Area under the curve =  0.906267954882216
# My model is lacking the confidence of  95.23 %
#
# XGBoost
#
# Accuracy :  0.9748892171344166
# True Negative :  1798
# False Positive :  14
# False Negative :  37
# True Positive :  182
# Precision :  0.9285714285714286
# Recall :  0.8310502283105022
# KS_score :  0.8233239589948289
# F1 Score :  0.8771084337349399
# Area under the curve =  0.9116619794974145
# My model is lacking the confidence of  6.46 %
#
# MLP Classifier
#
# Accuracy :  0.9768586903003447
# True Negative :  1769
# False Positive :  43
# False Negative :  4
# True Positive :  215
# Precision :  0.8333333333333334
# Recall :  0.9817351598173516
# KS_score :  0.9580044754906408
# F1 Score :  0.9014675052410902
# Area under the curve =  0.9790022377453205
# My model is lacking the confidence of  6.07 %
